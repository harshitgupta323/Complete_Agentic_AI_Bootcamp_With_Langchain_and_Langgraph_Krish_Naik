# %% [markdown]
# #### Embedding Techniques using HuggingFace

# %%
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
os.environ["HF_TOKEN"] = os.getenv("HF_TOKEN")

# %% [markdown]
# #### Sentence Transformers on Hugging Face
#
# Hugging Face sentence-transformers is a python framework for state-of-the-art sentence, text and image embeddings. One of the embeddings models is used in the HuggingFaceEmbeddings class. We have also added as alias for SebtenceTransformerEmbeddings for users who are more familiar with directly using that package.

# %%
from langchain_huggingface import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 3089.89it/s]

# %%
text = "this is a test document"
query_result = embeddings.embed_query(text)
query_result
# Out:
# [-0.048207879066467285,
#  0.11789611726999283,
#  -0.037469830363988876,
#  0.05662050098180771,
#  0.015501746907830238,
#  -0.036749329417943954,
#  -0.0595715306699276,
#  0.05720917880535126,
#  -0.02075636386871338,
#  0.057084690779447556,
#  0.07765143364667892,
#  0.018936678767204285,
#  0.0006362847634591162,
#  -0.0004040728963445872,
#  -0.06529418379068375,
#  -0.028550051152706146,
#  -0.011813553050160408,
#  -0.045690540224313736,
#  -0.00752565311267972,
#  0.08929037302732468,
#  0.05310378596186638,
#  0.06305596232414246,
#  -0.004552473779767752,
#  0.00036091101355850697,
#  0.008460184559226036,
#  0.030092932283878326,
#  -0.06308868527412415,
#  0.038058891892433167,
#  0.08158420026302338,
#  -0.05816446617245674,
#  0.032057568430900574,
#  0.06851983070373535,
#  0.07797115296125412,
#  0.034169286489486694,
#  0.0647691860795021,
#  0.004228692967444658,
#  0.07276926189661026,
#  0.0025179111398756504,
#  0.038405708968639374,
#  0.03519798070192337,
# ...
